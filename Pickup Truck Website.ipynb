# %% [markdown]
# ## Pickup Truck Webscrape

# %%
# Dependencies
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import urllib.request
import requests
import pandas as pd
import time
import re
import json
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import warnings

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
# Scrape Program

base_url = 'https://www.truecar.com/used-cars-for-sale/listings/body-truck/location-chicago-il/?accidentHistory=none&page='
tail = '&searchRadius=500'
page = 0
loops = 330
    
header = ['Brand','Model','Year','Trim','Drive','Description','Exterior Color','Interior Color','Miles','Price']
rows=[]
truck_data = pd.DataFrame(data=rows,columns=header)
#rowss= []
#rows1 = []
#trucks_data1 = pd.DataFrame(data=rows1,columns=header1)
    
    
for x in range(loops):
    page = x+1
    new_url = base_url+str(page)+tail
    html = requests.get(new_url)
    soup = BeautifulSoup(html.text,'lxml')
    #header = ['Brand','Model','Year','Trim','Drive','Description','Exterior Color','Interior Color','Miles','Price']

    div_list = soup.find_all('div', class_='card-content vehicle-card-body order-3')
    
    #rowss = []
    #rows = []

    for x in range(len(div_list)):

        # Start Row Addition----------------
        row = []

        # Call Truck HTML Data----------------
        truck = div_list[x]

        # Save Brand Data----------------
        try:
            brand = soup.find('span', class_='vehicle-header-make-model text-truncate').text
            num_brand= (len(brand))-(brand.find(" "))
            brand1 = brand[:-num_brand]
            row.append(brand1)
        except:
            row.append(np.nan)
            
        # Save Model Data----------------
        try:
            num_model = (brand.find(" "))+1
            model = brand[num_model:]
            row.append(model)
        except:
            row.append(np.nan)
            
        # Save Year Data----------------
        try:
            year = truck.find('span', class_='vehicle-card-year font-size-1').text
            row.append(year)
        except:
            row.append(np.nan)
            
        # Save Trim Data----------------
        try:
            desc = truck.find('div', class_='font-size-1 text-truncate').text
            num_trim = (len(desc))-(desc.find(" "))
            trim = desc[:-num_trim]
            row.append(trim)
        except:
            row.append(np.nan)
            
        # Save Drive Data----------------
        try:
            num_drive = (len(desc))-(desc.rfind(" "))-1
            drive = desc[-num_drive:]
            row.append(drive)
        except:
            row.append(np.nan)
            
        # Save Description Data----------------
        try:
            desc_mid1 = desc[(-num_trim)+1:]
            desc_mid2 = desc_mid1[:-num_drive]
            desc_mid3 = desc_mid2.strip()
            row.append(desc_mid2)
        except:
            row.append(np.nan)
            
        # Save Exterior Color Data----------------
        try:
            colors = truck.find('div',class_='vehicle-card-location font-size-1 margin-top-1 text-truncate').text
            num_col = (len(colors))-(colors.find(","))
            ext_col = colors[:-num_col]
            row.append(ext_col)
        except:
            row.append(np.nan)
            
        # Save Interior Color Data----------------
        try:
            num_inter_col = (colors.find(","))+2
            inter_col= colors[num_inter_col:]
            row.append(inter_col)
        except:
            row.append(np.nan)
            
        # Save Miles Data----------------
        try:
            miles = truck.find('div', class_='d-flex w-100 justify-content-between').text
            num_miles = (len(miles))-(miles.find(" "))
            miles1 = miles[:-num_miles]
            miles2 = re.sub('[!,]','',miles1)
            row.append(miles2)
        except:
            row.append(np.nan)
            
        # Save Price Data----------------
        try:
            price = truck.find('div', class_='heading-3 margin-y-1 font-weight-bold').text
            num_price = (len(price))-(1)
            price1 = price[-num_price:]
            price2 = re.sub('[!,]','',price1)
            row.append(price2)
        except:
            row.append(np.nan)
            
        rows.append(row)
    
truck_data = pd.DataFrame(data=rows,columns=header)

# %%
# Print Data Frame

truck_data.head(45)
# Out:
#         Brand           Model  Year     Trim      Drive  \
# 0        Ford           F-150  2015      XLT        4WD
# 1        Ford           F-150  2021               Sport
# 2        Ford           F-150  2016     High        4WD
# 3        Ford           F-150  2013      XLT        4WD
# 4        Ford           F-150  2010       XL        4WD
# 5        Ford           F-150  2018  Limited        4WD
# 6        Ford           F-150  2018       XL        4WD
# 7        Ford           F-150  2014  Laramie        4WD
# 8        Ford           F-150  2018       SV       Auto
# 9        Ford           F-150  2019      Big        2WD
# 10       Ford           F-150  2020   Lariat        4WD
# 11       Ford           F-150  2018       SR  Automatic
# 12       Ford           F-150  2017      XLT        4WD
# 13       Ford           F-150  2020    Rebel        4WD
# 14       Ford           F-150  2019      Z71        4WD
# 15       Ford           F-150  2018       XL        2WD
# 16       Ford           F-150  2018      XLT        4WD
# 17       Ford           F-150  2018       XL        4WD
# 18       Ford           F-150  2017    Night        4WD
# 19       Ford           F-150  2008       XL        RWD
# 20       Ford           F-150  2015       LT        4WD
# 21       Ford           F-150  2019      Big        4WD
# 22       Ford           F-150  2020             Rubicon
# 23       Ford           F-150  1998       XL        2WD
# 24       Ford           F-150  2019      XLT        4WD
# 25       Ford           F-150  2018      LTZ        4WD
# 26       Ford           F-150  2018      XLT        4WD
# 27       Ford           F-150  2017      SLT        2WD
# 28       Ford           F-150  2019      RST        4WD
# 29       Ford           F-150  2012       XL        RWD
# 30       Ford           F-150  2014      Big        4WD
# 31       Ford           F-150  2018      XLT        2WD
# 32       Ford           F-150  2020       LT        4WD
# 33  Chevrolet  Silverado 1500  2017       LT        4WD
# 34  Chevrolet  Silverado 1500  2009     3500        RWD
# 35  Chevrolet  Silverado 1500  2018       XL        4WD
# 36  Chevrolet  Silverado 1500  2019      XLT        4WD
# 37  Chevrolet  Silverado 1500  2019      XLT        2WD
# 38  Chevrolet  Silverado 1500  2020      RST        4WD
# 39  Chevrolet  Silverado 1500  2018      SR5        4WD
# 40  Chevrolet  Silverado 1500  2005      SLT        2WD
# 41  Chevrolet  Silverado 1500  2017      SLT        4WD
# 42  Chevrolet  Silverado 1500  2014      Big        4WD
# 43  Chevrolet  Silverado 1500  2019       XL        4WD
# 44  Chevrolet  Silverado 1500  2019      LTZ        4WD
#
#                           Description    Exterior Color    Interior Color  \
# 0                 SuperCrew 5.5' Box      Gray exterior    Black interior
# 1                                        Black exterior    Black interior
# 2         Country Crew Cab Short Box     Black exterior    Brown interior
# 3                 SuperCrew 5.5' Box     Black exterior     Gray interior
# 4                 SuperCrew 5.5' Box     White exterior  Unknown interior
# 5                 SuperCrew 5.5' Box     White exterior  Unknown interior
# 6                 SuperCrew 5.5' Box   Unknown exterior  Unknown interior
# 7                  Crew Cab 5'7" Box     Black exterior    Black interior
# 8                    V6 King Cab 4WD     White exterior     Gray interior
# 9             Horn Crew Cab 6'4" Box     White exterior    Black interior
# 10                SuperCrew 5.5' Box     Black exterior    Black interior
# 11          Double Cab 5' Bed V6 4WD    Silver exterior  Unknown interior
# 12                SuperCrew 5.5' Box     Black exterior     Gray interior
# 13                 Crew Cab 5'7" Box      Gray exterior    Black interior
# 14                Crew Cab Short Box      Blue exterior    Black interior
# 15              Regular Cab 6.5' Box     White exterior     Gray interior
# 16                SuperCrew 5.5' Box     White exterior     Gray interior
# 17                 SuperCab 6.5' Box     White exterior     Gray interior
# 18                 Crew Cab 5'7" Box       Red exterior    Black interior
# 19                  Regular Cab 137"     White exterior    Beige interior
# 20       with 1LT Crew Cab Short Box      Blue exterior    Black interior
# 21  Horn/Lone Star Crew Cab 5'7" Box     White exterior    Black interior
# 22                                        Gray exterior    Black interior
# 23       Flareside Supercab 6.5' Box       Red exterior  Unknown interior
# 24                SuperCrew 5.5' Box     Black exterior    Black interior
# 25                Crew Cab Short Box     White exterior    Black interior
# 26                SuperCrew 5.5' Box      Gray exterior     Gray interior
# 27                 Crew Cab 6'4" Box    Silver exterior     Gray interior
# 28           Double Cab Standard Box     Black exterior    Black interior
# 29                     SuperCab 142"     White exterior     Gray interior
# 30            Horn Crew Cab 5'7" Box      Blue exterior     Gray interior
# 31                 SuperCab 6.5' Box    Silver exterior     Gray interior
# 32                Crew Cab Short Bed    Silver exterior    Black interior
# 33             Crew Cab Standard Box       Red exterior    Black interior
# 34                  Work Van 177" WB     White exterior     Gray interior
# 35                 SuperCab 6.5' Box     Black exterior    Black interior
# 36                SuperCrew 5.5' Box    Silver exterior    Black interior
# 37                  SuperCrew 5' Box    Silver exterior    Black interior
# 38           Double Cab Standard Bed    Silver exterior    Black interior
# 39          CrewMax 5.5' Bed 5.7L V8    Silver exterior    Black interior
# 40           Regular Cab Regular Bed     White exterior  Unknown interior
# 41                 Quad Cab 6'4" Box     White exterior     Gray interior
# 42            Horn Crew Cab 6'4" Box    Silver exterior     Gray interior
# 43                SuperCrew 5.5' Box     White exterior    Black interior
# 44           Double Cab Standard Box     White exterior    Black interior
#
#      Miles  Price
# 0    38622  37499
# 1     3729  41590
# 2    69730  37958
# 3   116165  19995
# 4   157719  13495
# 5    43000  48472
# 6    34186  37155
# 7   111085  25395
# 8    45140  21949
# 9    63633  32000
# 10   60817  46990
# 11   13588  33355
# 12   75684  32998
# 13   57018  47450
# 14   56699  33695
# 15   86618  21750
# 16   44434  35081
# 17   23076  35080
# 18   49615  39777
# 19  114646  10950
# 20  142070  24795
# 21   42257  38999
# 22   18793  62988
# 23  169646   5999
# 24   30624  41492
# 25   48650  44895
# 26   65908  36110
# 27   52636  27900
# 28   30453  40914
# 29  168735  11950
# 30   43469  29995
# 31   88365  23995
# 32   22500  39999
# 33   37144  34998
# 34   41071  22203
# 35   95725  25888
# 36   28057  40998
# 37   29908  29998
# 38   41240  42388
# 39   66003  39995
# 40  113700   6000
# 41   73256  24912
# 42  240683  13950
# 43   32266  39476
# 44   47504  42000

# %%
truck_data.describe()
# Out:
#        Brand  Model  Year  Trim Drive          Description  Exterior Color  \
# count   9903   9903  9903  9903  9903                 9903            9903
# unique    10     27    26   102    54                  387              15
# top     Ford  F-150  2019   XLT   4WD  SuperCrew 5.5' Box   White exterior
# freq    2973   2523  2366  1436  7534                 1832            2696
#
#         Interior Color  Miles  Price
# count             9903   9903   9891
# unique               9   9435   4380
# top     Black interior  17883  39998
# freq              6209      4     50

# %%
# Drop Rows 

truck_data.dropna(axis=0, how='any', inplace=True)

# %%
truck_data['Price'] = truck_data['Price'].astype(int)
truck_data['Miles'] = truck_data['Miles'].astype(int)
truck_data['Year'] = truck_data['Year'].astype(int)

# %%
truck_data.dtypes
# Out:
# Brand             object
# Model             object
# Year               int32
# Trim              object
# Drive             object
# Description       object
# Exterior Color    object
# Interior Color    object
# Miles              int32
# Price              int32
# dtype: object

# %%
truck_data[['Miles','Price']].describe()
# Out:
#                Miles          Price
# count    9891.000000    9891.000000
# mean    50230.576180   39989.401880
# std     40029.971218   12395.339423
# min        11.000000    2800.000000
# 25%     21276.500000   32499.000000
# 50%     39893.000000   39000.000000
# 75%     68401.000000   46969.000000
# max    488580.000000  105000.000000

# %%
truck_data = truck_data[['Brand',
                         'Model',
                         'Year',
                         'Miles',
                         'Price'
                        ]]

# %%
truck_data.head(10)
# Out:
#   Brand  Model  Year   Miles  Price
# 0  Ford  F-150  2015   38622  37499
# 1  Ford  F-150  2021    3729  41590
# 2  Ford  F-150  2016   69730  37958
# 3  Ford  F-150  2013  116165  19995
# 4  Ford  F-150  2010  157719  13495
# 5  Ford  F-150  2018   43000  48472
# 6  Ford  F-150  2018   34186  37155
# 7  Ford  F-150  2014  111085  25395
# 8  Ford  F-150  2018   45140  21949
# 9  Ford  F-150  2019   63633  32000

# %%
truck_data.to_csv('truck_data12.csv',index=False,header=True)
print('File_Saved')
# Out:
# File_Saved

# %% [markdown]
# # Clean Truck Data From Kaggle (Historical 2018-2020)

# %%
file = 'Pickup_Data_Clean.csv'
df_all = pd.read_csv(file)
df_all.head(50)
# Out:
#     brandName  modelName  vf_ModelID  vf_ModelYear  mileage  askPrice   msrp  \
# 0        FORD      F-250      1805.0        2017.0    19106     40962  40962
# 1        FORD      F-150      1801.0        2017.0    28194     28962  28962
# 2         GMC     Sierra      1857.0        2017.0     7483     43962  43962
# 3        FORD      F-250      1805.0        2017.0    23881     38962  38962
# 4         GMC     Canyon      4093.0        2017.0     6333     30962  30962
# 5        FORD      F-150      1801.0        2016.0    26519     33962  33962
# 6        FORD      F-150      1801.0        2017.0    21638     30962  30962
# 7        FORD      F-150      1801.0        2016.0    23695     41962  41962
# 8        FORD      F-150      1801.0        2016.0    32084     28962  28962
# 9         RAM       2500     13621.0        2017.0    12084     41962  41962
# 10        RAM       1500     13620.0        2017.0    12315     36962  36962
# 11       FORD      F-150      1801.0        2017.0    22082     30962  30962
# 12       FORD      F-150      1801.0        2016.0    27536     31962  31962
# 13      DODGE        Ram      1938.0        2008.0   114152     14962  14962
# 14        RAM       2500     13621.0        2017.0    17273     41462  41462
# 15       FORD      F-150      1801.0        2016.0    34158     44962  44962
# 16        RAM       2500     13621.0        2016.0     8532     35462  35462
# 17        RAM       1500     13620.0        2014.0    44930     17962  17962
# 18       FORD      F-150      1801.0        2013.0    19039     26962  26962
# 19  CHEVROLET   Colorado      4086.0        2015.0    22459     29962  29962
# 20       FORD      F-250      1805.0        2016.0    59513     46962  46962
# 21        GMC     Canyon      4093.0        2017.0    17608     32962  32962
# 22        GMC     Sierra      1857.0        2016.0    20611     40962  40962
# 23       FORD      F-150      1801.0        2012.0   109254     20962  20962
# 24       FORD      F-150      1801.0        2015.0    26209     26962  26962
# 25       FORD      F-150      1801.0        2016.0    24049     33962  33962
# 26  CHEVROLET  Silverado      1850.0        2015.0    33794     29962  29962
# 27       FORD      F-150      1801.0        2016.0    47497     26962  26962
# 28       FORD      F-150      1801.0        2018.0    14315     29962  29962
# 29       FORD      F-150      1801.0        2017.0    12527     44962  44962
# 30       FORD      F-150      1801.0        2017.0    13189     42962  42962
# 31       FORD      F-150      1801.0        2015.0    36062     26962  26962
# 32       FORD      F-150      1801.0        2010.0   154556     13962  13962
# 33       FORD      F-150      1801.0        2015.0    42851     29962  29962
# 34      DODGE        Ram      1938.0        2012.0    45346     37962  37962
# 35       FORD      F-150      1801.0        2012.0   118696     19962  19962
# 36       FORD      F-150      1801.0        2015.0    42265     34962  34962
# 37       FORD      F-150      1801.0        2017.0    17073     34962  34962
# 38       FORD      F-150      1801.0        2015.0    44850     23962  23962
# 39       FORD      F-150      1801.0        2015.0    25082     38962  38962
# 40       FORD      F-150      1801.0        2016.0    18516     29962  29962
# 41        RAM       1500     13620.0        2016.0    43050     22962  22962
# 42       FORD      F-150      1801.0        2012.0   100151     21962  21962
# 43      DODGE        Ram      1938.0        2008.0   101638     10962  10962
# 44       FORD      F-350      1806.0        2009.0   126640     18962  18962
# 45       FORD      F-350      1806.0        2016.0    56531     45962  45962
# 46       FORD      F-350      1806.0        2012.0    14517     42962  42962
# 47        RAM       2500     13621.0        2017.0    22195     39962  39962
# 48        RAM       1500     13620.0        2017.0    25512     32962  32962
# 49        RAM       1500     13620.0        2013.0   120164     16962  16962
#
#                                  color  vf_EngineCylinders vf_FuelTypePrimary  \
# 0                Ingot Silver Metallic                 8.0             Diesel
# 1                Ingot Silver Metallic                 6.0           Gasoline
# 2                 Crimson Red Tintcoat                 8.0           Gasoline
# 3                         Oxford White                 8.0             Diesel
# 4                           Onyx Black                 6.0           Gasoline
# 5                         Oxford White                 8.0           Gasoline
# 6                         Shadow Black                 8.0           Gasoline
# 7                  Blue Flame Metallic                 6.0           Gasoline
# 8                         Oxford White                 8.0           Gasoline
# 9               Bright White Clearcoat                 6.0             Diesel
# 10              Bright White Clearcoat                 8.0           Gasoline
# 11               Ingot Silver Metallic                 6.0           Gasoline
# 12                            Magnetic                 6.0           Gasoline
# 13                           Flame Red                 8.0           Gasoline
# 14              Bright White Clearcoat                 6.0             Diesel
# 15                        Shadow Black                 6.0           Gasoline
# 16    Bright Silver Metallic Clearcoat                 8.0           Gasoline
# 17    Bright Silver Clearcoat Metallic                 6.0           Gasoline
# 18                 Blue Flame Metallic                 8.0           Gasoline
# 19                   Red Rock Metallic                 6.0           Gasoline
# 20                 Blue Jeans Metallic                 8.0             Diesel
# 21                          Onyx Black                 4.0             Diesel
# 22                          Onyx Black                 8.0           Gasoline
# 23               Tuxedo Black Metallic                 6.0           Gasoline
# 24               Tuxedo Black Metallic                 6.0           Gasoline
# 25                        Oxford White                 8.0           Gasoline
# 26                 Silver Ice Metallic                 8.0           Gasoline
# 27                        Shadow Black                 6.0           Gasoline
# 28                  Magma Red Metallic                 6.0           Gasoline
# 29                        Oxford White                 6.0           Gasoline
# 30                   Magnetic Metallic                 6.0           Gasoline
# 31               Tuxedo Black Metallic                 6.0           Gasoline
# 32                               Black                 8.0           Gasoline
# 33               Tuxedo Black Metallic                 6.0           Gasoline
# 34                     True Blue Pearl                 8.0             Diesel
# 35               Tuxedo Black Metallic                 6.0           Gasoline
# 36    White Platinum Metallic Tri-Coat                 8.0           Gasoline
# 37                        Oxford White                 8.0           Gasoline
# 38                               Black                 6.0           Gasoline
# 39                 Blue Jeans Metallic                 8.0           Gasoline
# 40                   Magnetic Metallic                 6.0           Gasoline
# 41  Granite Crystal Metallic Clearcoat                 8.0           Gasoline
# 42              Sterling Gray Metallic                 6.0           Gasoline
# 43              Cool Vanilla Clearcoat                 8.0           Gasoline
# 44        Royal Red Clearcoat Metallic                10.0           Gasoline
# 45                   Magnetic Metallic                 8.0             Diesel
# 46    White Platinum Metallic Tri-Coat                 8.0             Diesel
# 47    Bright Silver Clearcoat Metallic                 6.0             Diesel
# 48  Granite Crystal Metallic Clearcoat                 8.0           Gasoline
# 49                      Steel Metallic                 8.0           Gasoline
#
#                                                   vin
# 0   bcd4bbecbba3b9ed2330d543abc3d90b997aa8fa6e628d...
# 1   a8f09496d9523e33ee3a8f885a475f5ef001d68a334c98...
# 2   c65dd3e96f4f68a0d4c7b09005273e0312295057c7c529...
# 3   966168515802a7cf510d6c87a15cf71cc4385316a504c6...
# 4   9c7648c843035d0b46e9d716d947dfa3d0e8881054247a...
# 5   a7744ea6d085d017db4eb549ed430a4d4b8074c9cb1112...
# 6   258da8b91266c89798249877ed79bec864e49648eabd80...
# 7   cd4ba8b2c47e66a96b02a95521c480f918e7bd3a22944e...
# 8   34ad4bc5a8e0496ae7ed3315c2abda14eb2901f40615b1...
# 9   574ea1a1220ac84424596c4dae9737621a3246320f6c33...
# 10  d725fefa5f96440509a634324a13bc4575831232d47277...
# 11  be0bc2a06e8342be99553d2de691b3c1a1414820357455...
# 12  fdd5a712c586824eab91eafbdb1551092326122e74a93c...
# 13  e8c3a5a9970e84263e87d3fcf646975535685324a90cf5...
# 14  da8e89267adbc0dd8987c7a6a69619ab8f1ec81ec03751...
# 15  13f7708a8bc7a83487318ca4a0b5cd2622f2b93779c5fc...
# 16  c4fb87ff7115adbe7cfebdb1daf06b93034938513bc801...
# 17  7140d5acbc4c62669e9dea93a312bcb2e053d4dfbee5bd...
# 18  82a870c1a5c3b966461449866c49576ae6165d41b602f8...
# 19  4d232bb4aefcb25dc39db58dd780e1360222d1067f09dc...
# 20  4a0701399e45a3495f0486a8f068154eb1d887ece3c6ea...
# 21  046ca01b25baabf61a8eca73a262d0ac352585052d2057...
# 22  b8b9918691d0a9c36889a8040f4325ae432e90a6693bd6...
# 23  0119e5f0c1a102d2d87773b7fee2adf638bc2b288a456d...
# 24  7d8553a8bbea5b7e7b2f89c6c2fe137af29aeb45473977...
# 25  62f7bdb4ad4a3e6880b4ee270d5cfe720498cd2e86aeda...
# 26  080631a43afdae45c03d798b74495751db01714be935ca...
# 27  2d5f2e4780d2e26ee2cca98dd7feac880b280edf5ade37...
# 28  4fe8b7630ef2eea2c0c64fd084f91d57b9869fdb491454...
# 29  0c6a9ccc2e75e82632d33abcc3a46bdbbf6ea382090d77...
# 30  3826e5bd1c058fdd8dd2c678c0e559a5307e5767951d88...
# 31  0d910edb2a5b0d3539999a7615811e39ab091431eff2d4...
# 32  b7767df68cd930ec859993b7022eddf4a02bbc5b05f863...
# 33  3002cc9e2bff7f1538f21fa996300cbae12b51a711e295...
# 34  3d2de49b0a31f2dca6c8ae2d8981e286bc7c50eaf405a0...
# 35  b3b4e1995fcdd88c3f48fe3139dbe53b9c73ab572f2c03...
# 36  fa8e32ab3e5fa4e433f91caabdca0546d37e90adc059a4...
# 37  c304c12e1360b55dd8973639f4107d158b34043613c2be...
# 38  4d72001d71e85e43540d2f589802154f8cc1d6220ecde1...
# 39  1c4c4ff4339b7f5a669005c019b4f54c0698e82ef5ecb9...
# 40  3b232ea9b6dfcc762183145d6c28feb833e7ca893f4200...
# 41  a1e531cdb8ac4248923cc02e30f742d03daf8c6848f578...
# 42  4079bd88df33de5c878abea77efb9dcea8afbba0fc9e42...
# 43  a3eb1d29a4042c5ca951427c83cfee9dfbb31e4347902c...
# 44  af8d9d5841080015b6815102f631b99179d832934389fd...
# 45  07080609b61d6bc21e42a536bf351a4cdfecc55994f092...
# 46  210a05db503ee8fa74735ec343bf3d588e9de284ce34a7...
# 47  b147dea8092c0fead319446d3f05d5e0ea20d953293f76...
# 48  a1ab4b5b3f3cfbf07d5cb6d81a4640f849c37c7daf7a0f...
# 49  dce7ca8b27e60a012639966e864e5ba54db626b27b791f...

# %%
df_all.describe()
# Out:
#          vf_ModelID  vf_ModelYear        mileage      askPrice          msrp  \
# count  50788.000000  50788.000000   50788.000000  50788.000000  5.078800e+04
# mean    4210.843802   2014.094983   60745.412322  26767.678743  2.853393e+04
# std     4726.015433      4.001865   46278.783194   9963.884567  4.903721e+04
# min     1801.000000   1987.000000    1000.000000   5010.000000  5.010000e+03
# 25%     1801.000000   2012.000000   25372.500000  19995.000000  2.099800e+04
# 50%     1850.000000   2015.000000   46684.000000  27495.000000  2.899000e+04
# 75%     2467.000000   2017.000000   86193.250000  32990.000000  3.476175e+04
# max    25919.000000   2020.000000  249913.000000  54999.000000  1.000000e+07
#
#        vf_EngineCylinders
# count        50788.000000
# mean             7.223951
# std              1.071533
# min              4.000000
# 25%              6.000000
# 50%              8.000000
# 75%              8.000000
# max             10.000000

# %%
# Drop Columns

df_all = df_all[['brandName',
                 'modelName',
                 'vf_ModelYear',
                 'mileage',
                 'askPrice'
                      ]]

# %%
# Rename Columns

df_all = df_all.rename(columns={'brandName':'Brand',
                                 'modelName':'Model',
                                 'vf_ModelYear':'Year',
                                 'mileage':'Miles',
                                 'askPrice':'Price',}
          )

# %%
df_all['Year'] = df_all['Year'].astype(int)

# %%
df_all.dtypes
# Out:
# Brand    object
# Model    object
# Year      int32
# Miles     int64
# Price     int64
# dtype: object

# %%
df_all.head()
# Out:
#   Brand   Model  Year  Miles  Price
# 0  FORD   F-250  2017  19106  40962
# 1  FORD   F-150  2017  28194  28962
# 2   GMC  Sierra  2017   7483  43962
# 3  FORD   F-250  2017  23881  38962
# 4   GMC  Canyon  2017   6333  30962
